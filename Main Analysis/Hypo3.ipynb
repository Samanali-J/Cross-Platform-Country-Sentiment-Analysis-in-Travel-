# %%
import pandas as pd

# %%
you = pd.read_csv('youtube_county_mentioned_token_df.csv')
red = pd.read_csv('reddit_county_mentioned_token_df.csv')

# %%
import pandas as pd

youtube=you
reddit=red

# Rename columns to unify
youtube_renamed = youtube.rename(columns={
    'video_id': 'post_id',
    'comment_tokens': 'submission_tokens',
    'reply_tokens': 'comment_tokens',
    'comment_countries': 'submission_countries',
    'reply_countries': 'comment_countries'
})

# Add platform indicator
youtube_renamed['platform'] = 'YouTube'
reddit['platform'] = 'Reddit'

# Concatenate datasets
combined = pd.concat([youtube_renamed, reddit], ignore_index=True)

# Preview combined data
combined.head()
# Out:
#    year      post_id                                  submission_tokens  \
# 0  2025  40W27HZCcso  ['amaz', 'content', 'im', 'go', 'bali', 'year'...
# 1  2025  40W27HZCcso  ['amaz', 'content', 'im', 'go', 'bali', 'year'...
# 2  2025  40W27HZCcso  ['video', 'stun', 'watch', 'anyon', 'feel', 'l...
# 3  2025  40W27HZCcso  ['im', 'plan', 'visit', 'georgiamalaysiaturkey...
# 4  2025  40W27HZCcso          ['happi', 'new', 'year', 'gonna', 'sick']
#
#                                       comment_tokens  \
# 0  ['absolut', 'hope', 'great', 'trip', 'thank', ...
# 1  ['tri', 'get', 'travel', 'guid', 'go', 'wish',...
# 2                                                 []
# 3                     ['that', 'go', 'amaz', 'trip']
# 4                     ['cant', 'wait', 'see', 'get']
#
#                          submission_countries comment_countries platform
# 0         ['Japan', 'Indonesia', 'Singapore']                []  YouTube
# 1         ['Japan', 'Indonesia', 'Singapore']                []  YouTube
# 2                                          []                []  YouTube
# 3  ['Malaysia', 'Japan', 'Turkey', 'Georgia']                []  YouTube
# 4                                          []                []  YouTube

# %%
combined
# Out:
#       year      post_id                                  submission_tokens  \
# 0     2025  40W27HZCcso  ['amaz', 'content', 'im', 'go', 'bali', 'year'...
# 1     2025  40W27HZCcso  ['amaz', 'content', 'im', 'go', 'bali', 'year'...
# 2     2025  40W27HZCcso  ['video', 'stun', 'watch', 'anyon', 'feel', 'l...
# 3     2025  40W27HZCcso  ['im', 'plan', 'visit', 'georgiamalaysiaturkey...
# 4     2025  40W27HZCcso          ['happi', 'new', 'year', 'gonna', 'sick']
# ...    ...          ...                                                ...
# 5472  2018       aap3jo  ['updat', 'loser', 'whose', 'girlfriend', 'ric...
# 5473  2024      1b3m114  ['new', 'updat', 'aitah', 'cancel', 'wed', 'oo...
# 5474  2021       ql8klq  ['aita', 'call', 'sister', 'fuck', 'stupid', '...
# 5475  2024      1f6qm8k  ['im', 'australian', 'post', 'around', 'nine',...
# 5476  2022       vdmg5w  ['think', 'girlfriend', 'four', 'year', 'go', ...
#
#                                          comment_tokens  \
# 0     ['absolut', 'hope', 'great', 'trip', 'thank', ...
# 1     ['tri', 'get', 'travel', 'guid', 'go', 'wish',...
# 2                                                    []
# 3                        ['that', 'go', 'amaz', 'trip']
# 4                        ['cant', 'wait', 'see', 'get']
# ...                                                 ...
# 5472  ['dude', 'that', 'wonder', 'hear', 'realli', '...
# 5473  ['comment', 'origin', 'post', 'pleas', 'read',...
# 5474  ['obviou', 'nta', 'took', 'offer', 'fact', 'do...
# 5475  ['fun', 'that', 'main', 'object', 'nice', 'bal...
# 5476  ['pleas', 'read', 'sub', 'rule', 'comment', 'c...
#
#                                submission_countries  \
# 0               ['Japan', 'Indonesia', 'Singapore']
# 1               ['Japan', 'Indonesia', 'Singapore']
# 2                                                []
# 3        ['Malaysia', 'Japan', 'Turkey', 'Georgia']
# 4                                                []
# ...                                             ...
# 5472                    ['Mexico', 'United States']
# 5473                     ['Chile', 'United States']
# 5474                              ['United States']
# 5475  ['France', 'United States', 'United Kingdom']
# 5476       ['France', 'Australia', 'United States']
#
#                                       comment_countries platform
# 0                                                    []  YouTube
# 1                                                    []  YouTube
# 2                                                    []  YouTube
# 3                                                    []  YouTube
# 4                                                    []  YouTube
# ...                                                 ...      ...
# 5472  ['Russian Federation', 'Turkey', 'Mexico', 'Fr...   Reddit
# 5473  ['Thailand', 'Brazil', 'Chile', 'Spain', 'Pola...   Reddit
# 5474  ['Canada', 'Turkey', 'France', 'United Kingdom...   Reddit
# 5475  ['Canada', 'France', 'United Kingdom', 'Austra...   Reddit
# 5476           ['France', 'Australia', 'United States']   Reddit
#
# [5477 rows x 7 columns]

# %%
import pandas as pd
import networkx as nx
from collections import Counter

# Combine all country mentions per row
def extract_country_pairs(row):
    countries = []
    for col in ['submission_countries', 'comment_countries']:
        if pd.notnull(row[col]):
            countries.extend(row[col].strip('[]').replace("'", "").split(','))
    countries = [c.strip() for c in countries if c.strip()]
    return [(c1, c2) for i, c1 in enumerate(countries) for c2 in countries[i+1:]]

# Create co-mention pairs with year
# Assuming you already have a 'combined' DataFrame with relevant data
combined['country_pairs'] = combined.apply(extract_country_pairs, axis=1)

# Flatten and count co-mention pairs per year
pairs_per_year = {}
for year, group in combined.groupby('year'):
    pairs = [pair for sublist in group['country_pairs'] for pair in sublist]
    pair_counts = Counter(pairs)
    pairs_per_year[year] = pair_counts

# Iterate through years from 2018 to 2025 and create graph for each year
for year in range(2018, 2026):
    counts = pairs_per_year.get(year, {})
    
    if len(counts) == 0:
        print(f"Year {year}: No co-mention data available.")
        continue
    
    # Create an empty graph
    G = nx.Graph()
    
    # Add nodes and edges with weights (based on co-mention frequency)
    for (c1, c2), weight in counts.items():
        G.add_edge(c1, c2, weight=weight)
    
    # Save the graph as a .graphml file
    graph_filename = f'co_mention_network_{year}.graphml'
    nx.write_graphml(G, graph_filename)
    print(f"Graph for {year} saved as {graph_filename}")
# Out:
# Graph for 2018 saved as co_mention_network_2018.graphml
# Graph for 2019 saved as co_mention_network_2019.graphml
# Graph for 2020 saved as co_mention_network_2020.graphml
# Graph for 2021 saved as co_mention_network_2021.graphml
# Graph for 2022 saved as co_mention_network_2022.graphml
# Graph for 2023 saved as co_mention_network_2023.graphml
# Graph for 2024 saved as co_mention_network_2024.graphml
# Graph for 2025 saved as co_mention_network_2025.graphml

# %%
import pandas as pd
import networkx as nx
from collections import Counter

# List to store network size and density statistics
network_stats = []

for year, counts in pairs_per_year.items():
    G = nx.Graph()
    for (c1, c2), weight in counts.items():
        G.add_edge(c1, c2, weight=weight)
    
    # Network size: number of nodes and edges
    num_nodes = G.number_of_nodes()
    num_edges = G.number_of_edges()
    
    # Calculate network density
    density = nx.density(G)
    
    # Save results
    network_stats.append({
        'Year': year,
        'NumNodes': num_nodes,
        'NumEdges': num_edges,
        'Density': round(density, 4)
    })

# Output as DataFrame
network_stats_df = pd.DataFrame(network_stats)
network_stats_df
# Out:
#     Year  NumNodes  NumEdges  Density
# 0   2013        29       406   1.0000
# 1   2015        93      3204   0.7489
# 2   2016        47       620   0.5735
# 3   2017        44       315   0.3330
# 4   2018        20        90   0.4737
# 5   2019        82      1309   0.3942
# 6   2020       116      3264   0.4894
# 7   2021        94      1323   0.3027
# 8   2022        93      1940   0.4535
# 9   2023       116      2845   0.4265
# 10  2024       145      4903   0.4696
# 11  2025       145      5949   0.5698

# %%
import pandas as pd
import networkx as nx
from collections import Counter
from community import community_louvain
import matplotlib.pyplot as plt

# Combine all country mentions per row
def extract_country_pairs(row):
    countries = []
    for col in ['submission_countries', 'comment_countries']:
        if pd.notnull(row[col]):
            countries.extend(row[col].strip('[]').replace("'", "").split(','))
    countries = [c.strip() for c in countries if c.strip()]
    return [(c1, c2) for i, c1 in enumerate(countries) for c2 in countries[i+1:]]

# Create co-mention pairs with year
combined['country_pairs'] = combined.apply(extract_country_pairs, axis=1)

# Flatten and count co-mention pairs per year
pairs_per_year = {}
for year, group in combined.groupby('year'):
    pairs = [pair for sublist in group['country_pairs'] for pair in sublist]
    pair_counts = Counter(pairs)
    pairs_per_year[year] = pair_counts

# Build and analyze network per year
for year, counts in pairs_per_year.items():
    G = nx.Graph()
    for (c1, c2), weight in counts.items():
        G.add_edge(c1, c2, weight=weight)
    
    # Louvain community detection
    partition = community_louvain.best_partition(G, weight='weight')
    
    # Visualize network with communities
    pos = nx.spring_layout(G, seed=42)
    plt.figure(figsize=(10, 8))
    cmap = plt.get_cmap('tab20')
    nx.draw_networkx_nodes(G, pos, node_size=50, node_color=[partition[n] for n in G.nodes()], cmap=cmap)
    nx.draw_networkx_edges(G, pos, alpha=0.3)
    nx.draw_networkx_labels(G, pos, font_size=8)
    plt.title(f"Country Co-Mention Network with Louvain Communities ({year})")
    
    # Save the figure as a JPG file
    plt.savefig(f"co_mention_network_{year}.jpg", format='jpg', dpi=300)
    plt.close()

# %%
import pandas as pd
import networkx as nx
from collections import Counter
from community import community_louvain

# Define region/cultural groups dictionary
region_groups = {
    'ASEAN': {'Indonesia', 'Malaysia', 'Singapore', 'Thailand', 'Vietnam', 'Philippines', 'Brunei', 'Myanmar', 'Cambodia', 'Laos'},
    'EU': {'France', 'Germany', 'Italy', 'Spain', 'Netherlands', 'Belgium', 'Poland', 'Sweden', 'Denmark', 'Finland'},
    'North_America': {'USA', 'Canada', 'Mexico'},
    'East_Asia': {'China', 'Japan', 'South Korea', 'Taiwan', 'Hong Kong'},
    # Add more if necessary
}

# Extract and count country pairs by year
pairs_per_year = {}
for year, group in combined.groupby('year'):
    all_pairs = [pair for pairs_list in group['country_pairs'] if pairs_list for pair in pairs_list]
    pair_counts = Counter(all_pairs)
    pairs_per_year[year] = pair_counts

# Community detection and regional group matching
for year, counts in pairs_per_year.items():
    G = nx.Graph()
    for (c1, c2), weight in counts.items():
        G.add_edge(c1, c2, weight=weight)
    
    # Perform Louvain community detection
    partition = community_louvain.best_partition(G, weight='weight')
    
    # Group countries by community
    community_groups = {}
    for node, comm_id in partition.items():
        community_groups.setdefault(comm_id, set()).add(node)
    
    print(f"\n=== Year: {year} ===")
    for comm_id, countries in community_groups.items():
        print(f"Community {comm_id}: {countries}")

        # Evaluate matches with predefined regional groups
        for region, region_countries in region_groups.items():
            matched = countries & region_countries
            if matched:
                precision = len(matched) / len(countries)
                recall = len(matched) / len(region_countries)
                f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0
                print(f"  ↳ Region: {region}")
                print(f"    Matched Countries: {matched}")
                print(f"    Precision: {precision:.2f}, Recall: {recall:.2f}, F1: {f1:.2f}")
# Out:
# === Year: 2013 ===
# Community 0: {'Slovakia', 'Slovenia', 'Germany', 'United States', 'Romania', 'Czech Republic', 'Bulgaria', 'Sweden', 'Iceland', 'Ireland', 'Egypt', 'Canada', 'Denmark', 'Lithuania', 'Belgium', 'Réunion', 'Finland', 'Switzerland', 'Montenegro', 'Estonia', 'Norway', 'Poland', 'France', 'Croatia', 'Spain', 'Austria', 'United Kingdom', 'Latvia', 'Netherlands'}
#   ↳ Region: EU
#     Matched Countries: {'Belgium', 'Sweden', 'Poland', 'France', 'Finland', 'Germany', 'Spain', 'Netherlands', 'Denmark'}
#     Precision: 0.31, Recall: 0.90, F1: 0.46
#   ↳ Region: North_America
#     Matched Countries: {'Canada'}
#     Precision: 0.03, Recall: 0.33, F1: 0.06
#
# === Year: 2015 ===
# Community 0: {'Madagascar', 'Luxembourg', 'Georgia', 'Russian Federation', 'Kiribati', 'Turkmenistan', 'Afghanistan', 'Kenya', 'Congo', 'Lebanon', 'Jordan', 'India', 'Mexico', 'Guinea', 'Chad', 'Lesotho', 'Zambia', 'Morocco', 'Nauru', 'Rwanda', 'Sweden', 'Guyana', 'Panama', 'Gabon', 'Israel', 'Botswana', 'Bahrain', 'Ireland', 'Oman', 'Egypt', 'United Arab Emirates', 'Denmark', 'Belgium', 'Fiji', 'Finland', 'Cuba', 'Colombia', 'Turkey', 'Somalia', 'Palau', 'Qatar', 'Antarctica', 'Sudan', 'Angola', 'Yemen', 'Nicaragua', 'Samoa', 'Montenegro', 'Estonia', 'Azerbaijan', 'Norway', 'Ethiopia', 'Kazakhstan', 'Vietnam', 'Kuwait', 'France', 'Andorra', 'Malawi', 'Libya', 'Iraq', 'United Kingdom', 'Nepal', 'Eritrea', 'Uruguay', 'Guam', 'Latvia', 'Tuvalu', 'Algeria', 'Uzbekistan'}
#   ↳ Region: ASEAN
#     Matched Countries: {'Vietnam'}
#     Precision: 0.01, Recall: 0.10, F1: 0.03
#   ↳ Region: EU
#     Matched Countries: {'Belgium', 'Sweden', 'France', 'Finland', 'Denmark'}
#     Precision: 0.07, Recall: 0.50, F1: 0.13
#   ↳ Region: North_America
#     Matched Countries: {'Mexico'}
#     Precision: 0.01, Recall: 0.33, F1: 0.03
# Community 1: {'Brazil', 'Chile', 'Malaysia', 'Peru', 'United States', 'Czech Republic', 'China', 'Armenia', 'Iceland', 'Ukraine', 'Thailand', 'Italy', 'Canada', 'Albania', 'Japan', 'Greece', 'Portugal', 'Argentina', 'Spain', 'Australia'}
#   ↳ Region: ASEAN
#     Matched Countries: {'Thailand', 'Malaysia'}
#     Precision: 0.10, Recall: 0.20, F1: 0.13
#   ↳ Region: EU
#     Matched Countries: {'Italy', 'Spain'}
#     Precision: 0.10, Recall: 0.20, F1: 0.13
#   ↳ Region: North_America
#     Matched Countries: {'Canada'}
#     Precision: 0.05, Recall: 0.33, F1: 0.09
#   ↳ Region: East_Asia
#     Matched Countries: {'China', 'Japan'}
#     Precision: 0.10, Recall: 0.40, F1: 0.16
# Community 2: {'Germany', 'Netherlands', 'Slovenia'}
#   ↳ Region: EU
#     Matched Countries: {'Germany', 'Netherlands'}
#     Precision: 0.67, Recall: 0.20, F1: 0.31
# Community 3: {'Cyprus'}
#
# === Year: 2016 ===
# Community 1: {'Brazil', 'Bangladesh', 'Germany', 'United States', 'India', 'Mexico', 'Indonesia', 'Sweden', 'Botswana', 'Ireland', 'Italy', 'Serbia', 'United Arab Emirates', 'Fiji', 'Turkey', 'Qatar', 'Japan', 'Norway', 'Ethiopia', 'South Africa', 'Croatia', 'Spain', 'United Kingdom', 'Nepal', 'Uruguay', 'Australia', 'Netherlands'}
#   ↳ Region: ASEAN
#     Matched Countries: {'Indonesia'}
#     Precision: 0.04, Recall: 0.10, F1: 0.05
#   ↳ Region: EU
#     Matched Countries: {'Sweden', 'Germany', 'Spain', 'Italy', 'Netherlands'}
#     Precision: 0.19, Recall: 0.50, F1: 0.27
#   ↳ Region: North_America
#     Matched Countries: {'Mexico'}
#     Precision: 0.04, Recall: 0.33, F1: 0.07
#   ↳ Region: East_Asia
#     Matched Countries: {'Japan'}
#     Precision: 0.04, Recall: 0.20, F1: 0.06
# Community 2: {'Philippines', 'Colombia', 'Peru', 'Malta', 'Thailand'}
#   ↳ Region: ASEAN
#     Matched Countries: {'Thailand', 'Philippines'}
#     Precision: 0.40, Recall: 0.20, F1: 0.27
# Community 0: {'Guatemala', 'Czech Republic', 'Luxembourg', 'Vietnam', 'Mongolia', 'France', 'Chile', 'Cuba', 'Argentina', 'Iceland', 'Greenland', 'Bhutan', 'Greece'}
#   ↳ Region: ASEAN
#     Matched Countries: {'Vietnam'}
#     Precision: 0.08, Recall: 0.10, F1: 0.09
#   ↳ Region: EU
#     Matched Countries: {'France'}
#     Precision: 0.08, Recall: 0.10, F1: 0.09
# Community 4: {'Canada'}
#   ↳ Region: North_America
#     Matched Countries: {'Canada'}
#     Precision: 1.00, Recall: 0.33, F1: 0.50
# Community 3: {'Israel'}
#
# === Year: 2017 ===
# Community 1: {'Namibia', 'Finland'}
#   ↳ Region: EU
#     Matched Countries: {'Finland'}
#     Precision: 0.50, Recall: 0.10, F1: 0.17
# Community 4: {'Philippines', 'Portugal', 'Croatia', 'Germany', 'Spain', 'Turkey', 'Austria', 'Thailand', 'Italy', 'Mexico'}
#   ↳ Region: ASEAN
#     Matched Countries: {'Thailand', 'Philippines'}
#     Precision: 0.20, Recall: 0.20, F1: 0.20
#   ↳ Region: EU
#     Matched Countries: {'Germany', 'Italy', 'Spain'}
#     Precision: 0.30, Recall: 0.30, F1: 0.30
#   ↳ Region: North_America
#     Matched Countries: {'Mexico'}
#     Precision: 0.10, Recall: 0.33, F1: 0.15
# Community 7: {'Greece'}
# Community 6: {'Indonesia', 'Cambodia', 'Vietnam', 'Qatar', 'Peru', 'Japan', 'India', 'Australia', 'Netherlands'}
#   ↳ Region: ASEAN
#     Matched Countries: {'Vietnam', 'Indonesia', 'Cambodia'}
#     Precision: 0.33, Recall: 0.30, F1: 0.32
#   ↳ Region: EU
#     Matched Countries: {'Netherlands'}
#     Precision: 0.11, Recall: 0.10, F1: 0.11
#   ↳ Region: East_Asia
#     Matched Countries: {'Japan'}
#     Precision: 0.11, Recall: 0.20, F1: 0.14
# Community 3: {'Morocco', 'Kazakhstan', 'Georgia', 'Russian Federation', 'France', 'Armenia', 'Turkmenistan', 'Ukraine', 'Albania'}
#   ↳ Region: EU
#     Matched Countries: {'France'}
#     Precision: 0.11, Recall: 0.10, F1: 0.11
# Community 5: {'China', 'Libya', 'Iraq', 'United Kingdom', 'South Korea', 'United States', 'Yemen', 'Somalia', 'Sudan', 'United Arab Emirates', 'Canada'}
#   ↳ Region: North_America
#     Matched Countries: {'Canada'}
#     Precision: 0.09, Recall: 0.33, F1: 0.14
#   ↳ Region: East_Asia
#     Matched Countries: {'China', 'South Korea'}
#     Precision: 0.18, Recall: 0.40, F1: 0.25
# Community 0: {'Norway'}
# Community 2: {'Nepal'}
#
# === Year: 2018 ===
# Community 1: {'Germany', 'Italy', 'Zimbabwe', 'Jordan'}
#   ↳ Region: EU
#     Matched Countries: {'Germany', 'Italy'}
#     Precision: 0.50, Recall: 0.20, F1: 0.29
# Community 0: {'Australia', 'United Kingdom', 'Nepal', 'Canada'}
#   ↳ Region: North_America
#     Matched Countries: {'Canada'}
#     Precision: 0.25, Recall: 0.33, F1: 0.29
# Community 3: {'France', 'Turkey', 'United States', 'Japan', 'Mexico'}
#   ↳ Region: EU
#     Matched Countries: {'France'}
#     Precision: 0.20, Recall: 0.10, F1: 0.13
#   ↳ Region: North_America
#     Matched Countries: {'Mexico'}
#     Precision: 0.20, Recall: 0.33, F1: 0.25
#   ↳ Region: East_Asia
#     Matched Countries: {'Japan'}
#     Precision: 0.20, Recall: 0.20, F1: 0.20
# Community 2: {'Russian Federation', 'China', 'Libya', 'Afghanistan', 'Iraq', 'Israel', 'Yemen'}
#   ↳ Region: East_Asia
#     Matched Countries: {'China'}
#     Precision: 0.14, Recall: 0.20, F1: 0.17
#
# === Year: 2019 ===
# Community 0: {'Jamaica', 'Sweden', 'Pakistan', 'France', 'China', 'Colombia', 'South Korea', 'Qatar', 'United States', 'Israel', 'Uganda', 'Mexico', 'Denmark'}
#   ↳ Region: EU
#     Matched Countries: {'France', 'Sweden', 'Denmark'}
#     Precision: 0.23, Recall: 0.30, F1: 0.26
#   ↳ Region: North_America
#     Matched Countries: {'Mexico'}
#     Precision: 0.08, Recall: 0.33, F1: 0.12
#   ↳ Region: East_Asia
#     Matched Countries: {'China', 'South Korea'}
#     Precision: 0.15, Recall: 0.40, F1: 0.22
# Community 1: {'Aruba', 'Liberia', 'Morocco', 'Switzerland', 'Nepal', 'Uruguay', 'Bhutan', 'Netherlands'}
#   ↳ Region: EU
#     Matched Countries: {'Netherlands'}
#     Precision: 0.12, Recall: 0.10, F1: 0.11
# Community 3: {'Lithuania', 'Belarus', 'Belgium', 'Norway', 'Estonia', 'Poland', 'Russian Federation', 'Croatia', 'Finland', 'Germany', 'Hungary', 'United Kingdom', 'Ireland', 'Italy', 'Greece', 'Latvia'}
#   ↳ Region: EU
#     Matched Countries: {'Belgium', 'Poland', 'Finland', 'Germany', 'Italy'}
#     Precision: 0.31, Recall: 0.50, F1: 0.38
# Community 4: {'Ghana', 'Brazil', 'Cameroon', 'Chile', 'Kenya', 'Congo', 'Peru', 'Nigeria', 'India', 'Romania', 'Mali', 'Guinea', 'Chad', 'Djibouti', 'Zambia', 'Rwanda', 'Namibia', 'Gabon', 'Botswana', 'Egypt', 'Canada', 'Somalia', 'Japan', 'Sudan', 'Angola', 'Benin', 'Nicaragua', 'Ethiopia', 'Ecuador', 'Argentina', 'Malawi', 'Libya', 'Spain', 'Eritrea', 'Australia', 'Burundi'}
#   ↳ Region: EU
#     Matched Countries: {'Spain'}
#     Precision: 0.03, Recall: 0.10, F1: 0.04
#   ↳ Region: North_America
#     Matched Countries: {'Canada'}
#     Precision: 0.03, Recall: 0.33, F1: 0.05
#   ↳ Region: East_Asia
#     Matched Countries: {'Japan'}
#     Precision: 0.03, Recall: 0.20, F1: 0.05
# Community 2: {'Indonesia', 'Guatemala', 'Cambodia', 'Belize', 'Vietnam', 'Oman', 'Jordan', 'Thailand', 'Uzbekistan'}
#   ↳ Region: ASEAN
#     Matched Countries: {'Vietnam', 'Indonesia', 'Thailand', 'Cambodia'}
#     Precision: 0.44, Recall: 0.40, F1: 0.42
#
# === Year: 2020 ===
# Community 2: {'Philippines', 'Portugal', 'France', 'Slovenia', 'Croatia', 'Austria', 'United Kingdom', 'United States', 'Spain', 'Qatar', 'Italy', 'Greece'}
#   ↳ Region: ASEAN
#     Matched Countries: {'Philippines'}
#     Precision: 0.08, Recall: 0.10, F1: 0.09
#   ↳ Region: EU
#     Matched Countries: {'Italy', 'France', 'Spain'}
#     Precision: 0.25, Recall: 0.30, F1: 0.27
# Community 1: {'Belarus', 'Slovakia', 'Luxembourg', 'Georgia', 'Germany', 'Romania', 'Chad', 'Czech Republic', 'Bulgaria', 'Sweden', 'Armenia', 'Ukraine', 'Malta', 'Serbia', 'United Arab Emirates', 'Lithuania', 'Belgium', 'Hungary', 'Albania', 'Latvia', 'Montenegro', 'Liechtenstein', 'Estonia', 'Norway', 'Vietnam', 'Poland', 'Andorra', 'Australia', 'Monaco', 'Czechia'}
#   ↳ Region: ASEAN
#     Matched Countries: {'Vietnam'}
#     Precision: 0.03, Recall: 0.10, F1: 0.05
#   ↳ Region: EU
#     Matched Countries: {'Germany', 'Poland', 'Belgium', 'Sweden'}
#     Precision: 0.13, Recall: 0.40, F1: 0.20
# Community 3: {'Brazil', 'Russian Federation', 'Chile', 'Afghanistan', 'India', 'Mexico', 'Mongolia', 'China', 'Iceland', 'Jersey', 'Kyrgyzstan', 'Ireland', 'Thailand', 'Canada', 'Denmark', 'Aruba', 'Pakistan', 'Finland', 'Switzerland', 'Colombia', 'Turkey', 'Japan', 'Antarctica', 'Uganda', 'Netherlands', 'Tunisia', 'Azerbaijan', 'Kazakhstan', 'Argentina', 'Algeria', 'Nepal', 'Singapore', 'Uzbekistan'}
#   ↳ Region: ASEAN
#     Matched Countries: {'Thailand', 'Singapore'}
#     Precision: 0.06, Recall: 0.20, F1: 0.09
#   ↳ Region: EU
#     Matched Countries: {'Netherlands', 'Finland', 'Denmark'}
#     Precision: 0.09, Recall: 0.30, F1: 0.14
#   ↳ Region: North_America
#     Matched Countries: {'Mexico', 'Canada'}
#     Precision: 0.06, Recall: 0.67, F1: 0.11
#   ↳ Region: East_Asia
#     Matched Countries: {'China', 'Japan'}
#     Precision: 0.06, Recall: 0.40, F1: 0.11
# Community 4: {'Jamaica', 'Cambodia', 'Malaysia', 'Peru', 'Jordan', 'Mauritania', 'Indonesia', 'Myanmar', 'Panama', 'Israel', 'Fiji', 'Cuba', 'Gibraltar', 'Somalia', 'Sudan', 'Yemen', 'Ethiopia', 'Ecuador', 'Kuwait', 'Libya', 'Iraq', 'Uruguay', 'Paraguay'}
#   ↳ Region: ASEAN
#     Matched Countries: {'Indonesia', 'Malaysia', 'Cambodia', 'Myanmar'}
#     Precision: 0.17, Recall: 0.40, F1: 0.24
# Community 5: {'Zambia', 'Zimbabwe', 'Malawi'}
# Community 0: {'Madagascar', 'Togo', 'Ghana', 'Morocco', 'Seychelles', 'Senegal', 'Liberia', 'Namibia', 'South Africa', 'Kenya', 'Mauritius', 'Botswana', 'Nigeria', 'Egypt', 'Benin'}
#
# === Year: 2021 ===
# Community 0: {'Germany', 'Romania', 'Czech Republic', 'Armenia', 'Iceland', 'Ukraine', 'Malta', 'Ireland', 'Italy', 'Denmark', 'Cyprus', 'Switzerland', 'Hungary', 'Turkey', 'Greece', 'Montenegro', 'Norway', 'Portugal', 'Poland', 'Croatia', 'Austria', 'Spain', 'United Kingdom'}
#   ↳ Region: EU
#     Matched Countries: {'Poland', 'Germany', 'Spain', 'Italy', 'Denmark'}
#     Precision: 0.22, Recall: 0.50, F1: 0.30
# Community 1: {'Jamaica', 'Guatemala', 'Ghana', 'Luxembourg', 'Brazil', 'Georgia', 'Russian Federation', 'Chile', 'South Korea', 'United States', 'Mexico', 'Sweden', 'Bulgaria', 'China', 'Jersey', 'Israel', 'Serbia', 'Canada', 'Lithuania', 'Aruba', 'Belgium', 'Fiji', 'Finland', 'Cuba', 'Somalia', 'Antarctica', 'Uganda', 'Sudan', 'Yemen', 'Samoa', 'Estonia', 'Senegal', 'France', 'Argentina', 'Libya', 'Iraq', 'Uruguay', 'Australia', 'Latvia', 'Netherlands'}
#   ↳ Region: EU
#     Matched Countries: {'Belgium', 'Sweden', 'France', 'Finland', 'Netherlands'}
#     Precision: 0.12, Recall: 0.50, F1: 0.20
#   ↳ Region: North_America
#     Matched Countries: {'Mexico', 'Canada'}
#     Precision: 0.05, Recall: 0.67, F1: 0.09
#   ↳ Region: East_Asia
#     Matched Countries: {'China', 'South Korea'}
#     Precision: 0.05, Recall: 0.40, F1: 0.09
# Community 2: {'Indonesia', 'Philippines', 'Cambodia', 'Vietnam', 'Pakistan', 'Maldives', 'Jordan', 'Myanmar', 'Malaysia', 'Nepal', 'Japan', 'India', 'Thailand', 'Bhutan', 'Singapore', 'Oman'}
#   ↳ Region: ASEAN
#     Matched Countries: {'Indonesia', 'Cambodia', 'Philippines', 'Vietnam', 'Myanmar', 'Malaysia', 'Thailand', 'Singapore'}
#     Precision: 0.50, Recall: 0.80, F1: 0.62
#   ↳ Region: East_Asia
#     Matched Countries: {'Japan'}
#     Precision: 0.06, Recall: 0.20, F1: 0.10
# Community 3: {'Madagascar', 'Zambia', 'Morocco', 'Seychelles', 'Ethiopia', 'Tunisia', 'Namibia', 'Kenya', 'Mauritius', 'Botswana', 'Algeria', 'Nigeria', 'Zimbabwe', 'Egypt', 'Mauritania'}
#
# === Year: 2022 ===
# Community 0: {'Ghana', 'Brazil', 'Cameroon', 'Russian Federation', 'Slovenia', 'Chile', 'Afghanistan', 'Lebanon', 'Peru', 'Nigeria', 'Mexico', 'Czech Republic', 'Sweden', 'Namibia', 'United Arab Emirates', 'Egypt', 'Canada', 'Finland', 'Cuba', 'Somalia', 'Samoa', 'Estonia', 'Ethiopia', 'Haiti', 'Iraq', 'Austria', 'Australia', 'Latvia', 'Paraguay'}
#   ↳ Region: EU
#     Matched Countries: {'Finland', 'Sweden'}
#     Precision: 0.07, Recall: 0.20, F1: 0.10
#   ↳ Region: North_America
#     Matched Countries: {'Mexico', 'Canada'}
#     Precision: 0.07, Recall: 0.67, F1: 0.12
# Community 1: {'South Africa', 'Congo'}
# Community 2: {'Norway', 'Belarus', 'Portugal', 'Cyprus', 'Switzerland', 'Iceland', 'Germany', 'Spain', 'Italy', 'Netherlands', 'Greece'}
#   ↳ Region: EU
#     Matched Countries: {'Germany', 'Italy', 'Netherlands', 'Spain'}
#     Precision: 0.36, Recall: 0.40, F1: 0.38
# Community 3: {'Guatemala', 'Georgia', 'Kenya', 'Mali', 'Morocco', 'Kyrgyzstan', 'Jersey', 'Panama', 'Ireland', 'Denmark', 'Colombia', 'Turkey', 'Antarctica', 'Nicaragua', 'Azerbaijan', 'Kazakhstan', 'Ecuador', 'Poland', 'Croatia', 'Argentina', 'Libya', 'Algeria', 'Uruguay', 'Uzbekistan'}
#   ↳ Region: EU
#     Matched Countries: {'Poland', 'Denmark'}
#     Precision: 0.08, Recall: 0.20, F1: 0.12
# Community 4: {'Jamaica', 'Chad', 'Madagascar', 'Luxembourg', 'Belgium', 'France', 'China', 'United Kingdom', 'United States', 'Japan', 'Sudan', 'Yemen', 'Guinea'}
#   ↳ Region: EU
#     Matched Countries: {'France', 'Belgium'}
#     Precision: 0.15, Recall: 0.20, F1: 0.17
#   ↳ Region: East_Asia
#     Matched Countries: {'China', 'Japan'}
#     Precision: 0.15, Recall: 0.40, F1: 0.22
# Community 5: {'Indonesia', 'Cambodia', 'Philippines', 'Vietnam', 'Mongolia', 'Pakistan', 'Maldives', 'Jordan', 'Malaysia', 'Israel', 'Nepal', 'India', 'Thailand', 'Singapore'}
#   ↳ Region: ASEAN
#     Matched Countries: {'Indonesia', 'Cambodia', 'Philippines', 'Vietnam', 'Malaysia', 'Thailand', 'Singapore'}
#     Precision: 0.50, Recall: 0.70, F1: 0.58
#
# === Year: 2023 ===
# Community 3: {'Guatemala', 'Liberia', 'Slovenia', 'Germany', 'Mongolia', 'Ireland', 'Italy', 'Denmark', 'Lithuania', 'Fiji', 'Finland', 'Switzerland', 'Greece', 'Nicaragua', 'Norway', 'Poland', 'Spain', 'Nepal', 'Monaco'}
#   ↳ Region: EU
#     Matched Countries: {'Poland', 'Finland', 'Germany', 'Spain', 'Italy', 'Denmark'}
#     Precision: 0.32, Recall: 0.60, F1: 0.41
# Community 1: {'Slovakia', 'Cambodia', 'Brazil', 'Georgia', 'Russian Federation', 'Chile', 'South Korea', 'Peru', 'United States', 'India', 'Czechia', 'Romania', 'Mexico', 'Czech Republic', 'Bulgaria', 'China', 'Iceland', 'Panama', 'Jersey', 'Myanmar', 'Malta', 'Canada', 'Belgium', 'Anguilla', 'Colombia', 'Palau', 'Japan', 'Antarctica', 'Angola', 'Sudan', 'Liechtenstein', 'Ecuador', 'France', 'Croatia', 'Bermuda', 'Argentina', 'Guam', 'Haiti', 'Andorra', 'United Kingdom', 'Uruguay', 'Australia', 'Latvia', 'Netherlands', 'Paraguay'}
#   ↳ Region: ASEAN
#     Matched Countries: {'Cambodia', 'Myanmar'}
#     Precision: 0.04, Recall: 0.20, F1: 0.07
#   ↳ Region: EU
#     Matched Countries: {'Netherlands', 'France', 'Belgium'}
#     Precision: 0.07, Recall: 0.30, F1: 0.11
#   ↳ Region: North_America
#     Matched Countries: {'Mexico', 'Canada'}
#     Precision: 0.04, Recall: 0.67, F1: 0.08
#   ↳ Region: East_Asia
#     Matched Countries: {'China', 'South Korea', 'Japan'}
#     Precision: 0.07, Recall: 0.60, F1: 0.12
# Community 2: {'Jamaica', 'Tajikistan', 'Bangladesh', 'Afghanistan', 'Malaysia', 'Lebanon', 'Jordan', 'Guinea', 'Indonesia', 'Sweden', 'Kyrgyzstan', 'Gambia', 'Israel', 'Oman', 'Bahrain', 'Thailand', 'United Arab Emirates', 'Philippines', 'Pakistan', 'Cuba', 'Turkey', 'Somalia', 'Qatar', 'Albania', 'Tunisia', 'Yemen', 'Azerbaijan', 'Kazakhstan', 'Vietnam', 'Kuwait', 'Iraq', 'Austria', 'Algeria', 'Maldives', 'Singapore', 'Uzbekistan'}
#   ↳ Region: ASEAN
#     Matched Countries: {'Indonesia', 'Philippines', 'Vietnam', 'Malaysia', 'Thailand', 'Singapore'}
#     Precision: 0.17, Recall: 0.60, F1: 0.26
#   ↳ Region: EU
#     Matched Countries: {'Sweden'}
#     Precision: 0.03, Recall: 0.10, F1: 0.04
# Community 0: {'Chad', 'Zambia', 'Madagascar', 'Morocco', 'Rwanda', 'Ethiopia', 'Ghana', 'Seychelles', 'Namibia', 'Malawi', 'Kenya', 'Mauritius', 'Botswana', 'Uganda', 'Egypt', 'Benin'}
#
# === Year: 2024 ===
# Community 0: {'Chad', 'Togo', 'Tunisia', 'Kuwait', 'France', 'Jordan', 'Switzerland', 'Libya', 'Tonga', 'Jersey', 'United Kingdom', 'United States', 'Nigeria', 'India', 'Greece', 'Benin', 'Mauritania'}
#   ↳ Region: EU
#     Matched Countries: {'France'}
#     Precision: 0.06, Recall: 0.10, F1: 0.07
# Community 1: {'Zambia', 'Indonesia', 'Philippines', 'Vietnam', 'China', 'Maldives', 'Bermuda', 'Malaysia', 'Iraq', 'Timor-Leste', 'Israel', 'Japan', 'Thailand', 'Bhutan', 'Singapore'}
#   ↳ Region: ASEAN
#     Matched Countries: {'Indonesia', 'Philippines', 'Vietnam', 'Malaysia', 'Thailand', 'Singapore'}
#     Precision: 0.40, Recall: 0.60, F1: 0.48
#   ↳ Region: East_Asia
#     Matched Countries: {'China', 'Japan'}
#     Precision: 0.13, Recall: 0.40, F1: 0.20
# Community 3: {'Ghana', 'Liberia', 'Cambodia', 'Tajikistan', 'Bangladesh', 'Afghanistan', 'Kenya', 'Turkmenistan', 'Congo', 'South Korea', 'Mali', 'Djibouti', 'Lesotho', 'Morocco', 'Bulgaria', 'Namibia', 'Mongolia', 'Armenia', 'Myanmar', 'Kyrgyzstan', 'Gambia', 'Botswana', 'Oman', 'Bahrain', 'Serbia', 'United Arab Emirates', 'Egypt', 'Aruba', 'Pakistan', 'Mauritius', 'Somalia', 'Qatar', 'Sudan', 'Uganda', 'Angola', 'Nicaragua', 'Yemen', 'Montenegro', 'Azerbaijan', 'Senegal', 'Ethiopia', 'Kazakhstan', 'Vanuatu', 'Malawi', 'Nepal', 'Algeria', 'Monaco', 'Uzbekistan'}
#   ↳ Region: ASEAN
#     Matched Countries: {'Cambodia', 'Myanmar'}
#     Precision: 0.04, Recall: 0.20, F1: 0.07
#   ↳ Region: East_Asia
#     Matched Countries: {'South Korea'}
#     Precision: 0.02, Recall: 0.20, F1: 0.04
# Community 2: {'Jamaica', 'Honduras', 'Belarus', 'Guatemala', 'Belize', 'Chile', 'Peru', 'Guinea', 'Guyana', 'Ukraine', 'Panama', 'Greenland', 'Dominica', 'Albania', 'Antarctica', 'Grenada', 'Liechtenstein', 'Portugal', 'Ecuador', 'South Africa', 'Argentina', 'Haiti', 'Uruguay', 'Paraguay'}
# Community 4: {'Luxembourg', 'Slovakia', 'Brazil', 'Georgia', 'Russian Federation', 'Slovenia', 'Eswatini', 'Kiribati', 'Germany', 'Lebanon', 'Czechia', 'Romania', 'Mexico', 'Czech Republic', 'Sweden', 'Iceland', 'Ireland', 'Malta', 'Italy', 'Canada', 'Denmark', 'Lithuania', 'Belgium', 'Fiji', 'Finland', 'Cuba', 'Colombia', 'Turkey', 'Estonia', 'Norway', 'Poland', 'Croatia', 'Guam', 'Andorra', 'Spain', 'Austria', 'Eritrea', 'Tuvalu', 'Australia', 'Latvia', 'Netherlands'}
#   ↳ Region: EU
#     Matched Countries: {'Belgium', 'Sweden', 'Poland', 'Finland', 'Germany', 'Spain', 'Italy', 'Netherlands', 'Denmark'}
#     Precision: 0.22, Recall: 0.90, F1: 0.35
#   ↳ Region: North_America
#     Matched Countries: {'Mexico', 'Canada'}
#     Precision: 0.05, Recall: 0.67, F1: 0.09
#
# === Year: 2025 ===
# Community 1: {'Liechtenstein', 'Indonesia', 'Chad', 'Philippines', 'Brazil', 'Georgia', 'Vietnam', 'Cambodia', 'Armenia', 'Malaysia', 'Turkey', 'South Korea', 'Nepal', 'Japan', 'Macao', 'Australia', 'Bhutan', 'Singapore'}
#   ↳ Region: ASEAN
#     Matched Countries: {'Indonesia', 'Cambodia', 'Philippines', 'Vietnam', 'Malaysia', 'Singapore'}
#     Precision: 0.33, Recall: 0.60, F1: 0.43
#   ↳ Region: East_Asia
#     Matched Countries: {'South Korea', 'Japan'}
#     Precision: 0.11, Recall: 0.40, F1: 0.17
# Community 2: {'Jamaica', 'Slovakia', 'Afghanistan', 'Lebanon', 'India', 'Mexico', 'China', 'Myanmar', 'Jersey', 'Israel', 'Bahrain', 'Thailand', 'Italy', 'Somalia', 'Antarctica', 'Libya', 'Haiti', 'Iraq', 'Monaco', 'Czechia'}
#   ↳ Region: ASEAN
#     Matched Countries: {'Thailand', 'Myanmar'}
#     Precision: 0.10, Recall: 0.20, F1: 0.13
#   ↳ Region: EU
#     Matched Countries: {'Italy'}
#     Precision: 0.05, Recall: 0.10, F1: 0.07
#   ↳ Region: North_America
#     Matched Countries: {'Mexico'}
#     Precision: 0.05, Recall: 0.33, F1: 0.09
#   ↳ Region: East_Asia
#     Matched Countries: {'China'}
#     Precision: 0.05, Recall: 0.20, F1: 0.08
# Community 0: {'Madagascar', 'Luxembourg', 'Russian Federation', 'Tajikistan', 'Eswatini', 'Turkmenistan', 'Bangladesh', 'Kenya', 'Congo', 'Jordan', 'Romania', 'Zambia', 'Lesotho', 'Czech Republic', 'Morocco', 'Sweden', 'Bulgaria', 'Rwanda', 'Namibia', 'Mongolia', 'Iceland', 'Kyrgyzstan', 'Greenland', 'Malta', 'Oman', 'Botswana', 'Serbia', 'Egypt', 'United Arab Emirates', 'Belgium', 'Fiji', 'Pakistan', 'Finland', 'Cuba', 'Dominica', 'Qatar', 'Palau', 'Sudan', 'Uganda', 'Yemen', 'Estonia', 'Norway', 'Kazakhstan', 'Azerbaijan', 'Ethiopia', 'Vanuatu', 'South Africa', 'Kuwait', 'Malawi', 'Algeria', 'Tuvalu', 'Burundi', 'Uzbekistan'}
#   ↳ Region: EU
#     Matched Countries: {'Finland', 'Belgium', 'Sweden'}
#     Precision: 0.06, Recall: 0.30, F1: 0.10
# Community 4: {'Guatemala', 'Lithuania', 'Portugal', 'Ecuador', 'Poland', 'Chile', 'Paraguay', 'Argentina', 'Colombia', 'Guyana', 'Panama', 'Peru', 'Uruguay', 'Curaçao', 'Latvia', 'Tunisia', 'Nicaragua'}
#   ↳ Region: EU
#     Matched Countries: {'Poland'}
#     Precision: 0.06, Recall: 0.10, F1: 0.07
# Community 5: {'Montenegro', 'Slovenia', 'Croatia', 'Albania', 'Maldives', 'Greece'}
# Community 6: {'Aruba', 'France', 'Andorra', 'Grenada', 'Switzerland', 'Guam', 'Germany', 'Austria', 'Spain', 'United States', 'Ireland', 'United Kingdom', 'Montserrat', 'Netherlands', 'Canada', 'Denmark', 'Djibouti'}
#   ↳ Region: EU
#     Matched Countries: {'France', 'Germany', 'Spain', 'Netherlands', 'Denmark'}
#     Precision: 0.29, Recall: 0.50, F1: 0.37
#   ↳ Region: North_America
#     Matched Countries: {'Canada'}
#     Precision: 0.06, Recall: 0.33, F1: 0.10
# Community 3: {'Togo', 'Ghana', 'Liberia', 'Cameroon', 'Gibraltar', 'Gabon', 'Gambia', 'Mauritius', 'Mali', 'Nigeria', 'Angola', 'Guinea', 'Benin', 'Mauritania'}

# %%
import matplotlib.pyplot as plt
import networkx as nx
import random

for year, counts in pairs_per_year.items():
    G = nx.Graph()
    for (c1, c2), weight in counts.items():
        G.add_edge(c1, c2, weight=weight)
    
    # Perform Louvain community detection
    partition = community_louvain.best_partition(G, weight='weight')
    
    if len(G.nodes()) == 0:
        print(f"Year {year}: No nodes to visualize.")
        continue

    # Assign colors to nodes based on their community
    unique_comms = list(set(partition.values()))
    colors = plt.cm.tab20(range(len(unique_comms)))
    comm_colors = {comm: colors[idx % len(colors)] for idx, comm in enumerate(unique_comms)}
    node_colors = [comm_colors[partition[node]] for node in G.nodes()]

    # Set node positions
    pos = nx.spring_layout(G, seed=42)
    
    # Draw the network graph
    plt.figure(figsize=(10, 8))
    nx.draw_networkx_nodes(G, pos, node_size=300, node_color=node_colors)
    nx.draw_networkx_edges(G, pos, alpha=0.3)
    nx.draw_networkx_labels(G, pos, font_size=8)
    plt.title(f"Louvain Community Visualization for {year}")
    plt.axis('off')
    plt.tight_layout()
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# List to store results
results = []

# Loop through each year and compute community matching metrics
for year, counts in pairs_per_year.items():
    G = nx.Graph()
    for (c1, c2), weight in counts.items():
        G.add_edge(c1, c2, weight=weight)
    partition = community_louvain.best_partition(G, weight='weight')
    
    community_groups = {}
    for node, comm_id in partition.items():
        community_groups.setdefault(comm_id, set()).add(node)
    
    # Calculate precision, recall, and F1 score for each community-region pair
    for comm_id, countries in community_groups.items():
        for region, region_countries in region_groups.items():
            matched = countries & region_countries
            if matched:
                precision = len(matched) / len(countries)
                recall = len(matched) / len(region_countries)
                f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0
                results.append({
                    'Year': year,
                    'Community': comm_id,
                    'Region': region,
                    'NumCountries': len(countries),
                    'MatchedCountries': len(matched),
                    'Precision': precision,
                    'Recall': recall,
                    'F1': f1
                })

# Convert the results list to a DataFrame
results_df = pd.DataFrame(results)
print(results_df)

# 📈 Visualize average Precision, Recall, and F1 score per year
avg_per_year = results_df.groupby('Year')[['Precision', 'Recall', 'F1']].mean().reset_index()
plt.figure(figsize=(10,6))
plt.plot(avg_per_year['Year'], avg_per_year['Precision'], marker='o', label='Precision')
plt.plot(avg_per_year['Year'], avg_per_year['Recall'], marker='o', label='Recall')
plt.plot(avg_per_year['Year'], avg_per_year['F1'], marker='o', label='F1')
plt.xlabel('Year')
plt.ylabel('Score')
plt.title('Yearly Average Precision, Recall, F1')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig('yearly_avg_metrics.png', dpi=300)
plt.show()
# Out:
#     Year  Community         Region  NumCountries  MatchedCountries  Precision  \
# 0   2013          0             EU            29                 9   0.310345
# 1   2013          0  North_America            29                 1   0.034483
# 2   2015          0          ASEAN            69                 1   0.014493
# 3   2015          0             EU            69                 5   0.072464
# 4   2015          0  North_America            69                 1   0.014493
# ..   ...        ...            ...           ...               ...        ...
# 88  2025          1      East_Asia            18                 1   0.055556
# 89  2025          5             EU            57                 3   0.052632
# 90  2025          4             EU            14                 1   0.071429
# 91  2025          3             EU            16                 5   0.312500
# 92  2025          3  North_America            16                 1   0.062500
#
#       Recall        F1
# 0   0.900000  0.461538
# 1   0.333333  0.062500
# 2   0.100000  0.025316
# 3   0.500000  0.126582
# 4   0.333333  0.027778
# ..       ...       ...
# 88  0.200000  0.086957
# 89  0.300000  0.089552
# 90  0.100000  0.083333
# 91  0.500000  0.384615
# 92  0.333333  0.105263
#
# [93 rows x 8 columns]

# %%
betweenness_results = []

for year, counts in pairs_per_year.items():
    G = nx.Graph()
    for (c1, c2), weight in counts.items():
        G.add_edge(c1, c2, weight=weight)
    
    betweenness_centrality = nx.betweenness_centrality(G, weight='weight')
    
    top_betweenness = pd.DataFrame({
        'Year': year,
        'Country': list(betweenness_centrality.keys()),
        'Betweenness_Centrality': list(betweenness_centrality.values())
    }).sort_values(by='Betweenness_Centrality', ascending=False).head(5)
    
    betweenness_results.extend(top_betweenness.to_dict('records'))

betweenness_df = pd.DataFrame(betweenness_results)
betweenness_df.head()
# Out:
#    Year      Country  Betweenness_Centrality
# 0  2013     Bulgaria                     0.0
# 1  2013      Denmark                     0.0
# 2  2013       France                     0.0
# 3  2013       Sweden                     0.0
# 4  2013  Netherlands                     0.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select top 5 countries by Betweenness Centrality for each year
top5_df = betweenness_df.groupby('Year').apply(lambda x: x.nlargest(5, 'Betweenness_Centrality')).reset_index(drop=True)

# Visualization
plt.figure(figsize=(12, 6))
sns.barplot(x='Year', y='Betweenness_Centrality', hue='Country', data=top5_df, dodge=True)
plt.title('Top 5 Countries by Betweenness Centrality per Year')
plt.ylabel('Betweenness Centrality')
plt.xlabel('Year')
plt.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import os

# List of target countries (EU + ASEAN)
eu_asean_countries = [
    'France', 'Germany', 'Sweden', 'Belgium', 'Denmark', 'Poland', 'Finland', 'Italy', 'Spain',
    'Thailand', 'Vietnam', 'Indonesia', 'Malaysia', 'Singapore', 'Cambodia', 'Philippines', 'Myanmar'
]

# Create directory for saving GraphML files
os.makedirs('graphml_files', exist_ok=True)

for year, counts in pairs_per_year.items():
    G = nx.Graph()
    for (c1, c2), weight in counts.items():
        # Include only EU + ASEAN countries
        if c1 in eu_asean_countries and c2 in eu_asean_countries:
            G.add_edge(c1, c2, weight=weight)

    if len(G.nodes()) == 0:
        print(f"\n=== Year: {year} ===\nNo EU/ASEAN nodes to visualize.")
        continue

    # Calculate centrality
    degree_centrality = nx.degree_centrality(G)
    betweenness_centrality = nx.betweenness_centrality(G, weight='weight')

    # Add node attributes
    nx.set_node_attributes(G, degree_centrality, 'degree_centrality')
    nx.set_node_attributes(G, betweenness_centrality, 'betweenness_centrality')

    pos = nx.spring_layout(G, seed=42)
    node_size = [5000 * degree_centrality[n] for n in G.nodes()]
    node_color = [betweenness_centrality[n] for n in G.nodes()]

    plt.figure(figsize=(10, 8))
    nodes = nx.draw_networkx_nodes(G, pos, node_size=node_size, node_color=node_color, cmap=plt.cm.viridis)
    nx.draw_networkx_edges(G, pos, alpha=0.3)
    nx.draw_networkx_labels(G, pos, font_size=8, font_color='white', font_weight='bold')
    plt.title(f"Year {year}: EU & ASEAN Node Size=Degree, Color=Betweenness")
    plt.colorbar(nodes, label='Betweenness Centrality')
    plt.tight_layout()
    plt.savefig(f'centrality_visualization_{year}_EU_ASEAN.png', dpi=300)
    plt.show()

    # Print top centrality
    top_degree = pd.DataFrame({
        'Year': year,
        'Country': list(degree_centrality.keys()),
        'DegreeCentrality': list(degree_centrality.values()),
        'BetweennessCentrality': [betweenness_centrality[n] for n in G.nodes()]
    }).sort_values(by='DegreeCentrality', ascending=False).head(5)

    top_betweenness = pd.DataFrame({
        'Year': year,
        'Country': list(betweenness_centrality.keys()),
        'DegreeCentrality': list(degree_centrality.values()),
        'BetweennessCentrality': [betweenness_centrality[n] for n in G.nodes()]
    }).sort_values(by='BetweennessCentrality', ascending=False).head(5)

    print(f"\n=== Year: {year} ===")
    print("Top Degree Centrality:")
    print(top_degree)
    print("Top Betweenness Centrality:")
    print(top_betweenness)

    # Print top 5 strongest connections (Edge weight)
    top_edges = sorted(G.edges(data=True), key=lambda x: x[2]['weight'], reverse=True)[:5]
    print("\nTop 5 Strongest Connections (Edge weight):")
    for u, v, data in top_edges:
        print(f"{u} - {v}: weight={data['weight']}")

    # Save GraphML file
    graphml_filename = f'graphml_files/network_{year}_EU_ASEAN.graphml'
    nx.write_graphml(G, graphml_filename)
    print(f"GraphML file saved: {graphml_filename}")
# Out:
# === Year: 2013 ===
# Top Degree Centrality:
#    Year  Country  DegreeCentrality  BetweennessCentrality
# 0  2013  Germany               1.0                    0.0
# 1  2013    Spain               1.0                    0.0
# 2  2013  Finland               1.0                    0.0
# 3  2013  Belgium               1.0                    0.0
# 4  2013  Denmark               1.0                    0.0
# Top Betweenness Centrality:
#    Year  Country  DegreeCentrality  BetweennessCentrality
# 0  2013  Germany               1.0                    0.0
# 1  2013    Spain               1.0                    0.0
# 2  2013  Finland               1.0                    0.0
# 3  2013  Belgium               1.0                    0.0
# 4  2013  Denmark               1.0                    0.0
#
# Top 5 Strongest Connections (Edge weight):
# Germany - Spain: weight=1
# Germany - Finland: weight=1
# Germany - Belgium: weight=1
# Germany - Denmark: weight=1
# Germany - Poland: weight=1
# GraphML file saved: graphml_files/network_2013_EU_ASEAN.graphml
# === Year: 2015 ===
# Top Degree Centrality:
#    Year   Country  DegreeCentrality  BetweennessCentrality
# 1  2015  Thailand          1.000000               0.000000
# 2  2015     Spain          1.000000               0.000000
# 3  2015  Malaysia          1.000000               0.222222
# 4  2015   Vietnam          0.888889               0.023148
# 5  2015   Denmark          0.888889               0.023148
# Top Betweenness Centrality:
#    Year   Country  DegreeCentrality  BetweennessCentrality
# 3  2015  Malaysia          1.000000               0.222222
# 4  2015   Vietnam          0.888889               0.023148
# 5  2015   Denmark          0.888889               0.023148
# 6  2015   Belgium          0.888889               0.023148
# 7  2015    Sweden          0.888889               0.023148
#
# Top 5 Strongest Connections (Edge weight):
# Thailand - Spain: weight=10
# Italy - Thailand: weight=9
# Italy - Spain: weight=9
# Thailand - Malaysia: weight=3
# Spain - Malaysia: weight=3
# GraphML file saved: graphml_files/network_2015_EU_ASEAN.graphml
# === Year: 2016 ===
# Top Degree Centrality:
#    Year   Country  DegreeCentrality  BetweennessCentrality
# 0  2016  Thailand             1.250               0.250000
# 1  2016    France             1.125               0.000000
# 3  2016     Italy             1.125               0.035714
# 6  2016   Vietnam             1.125               0.011905
# 2  2016     Spain             0.875               0.035714
# Top Betweenness Centrality:
#    Year   Country  DegreeCentrality  BetweennessCentrality
# 0  2016  Thailand             1.250               0.250000
# 2  2016     Spain             0.875               0.035714
# 3  2016     Italy             1.125               0.035714
# 7  2016   Germany             0.875               0.035714
# 8  2016    Sweden             0.875               0.035714
#
# Top 5 Strongest Connections (Edge weight):
# Thailand - Thailand: weight=4
# Thailand - France: weight=3
# Thailand - Indonesia: weight=2
# France - Vietnam: weight=2
# Thailand - Spain: weight=1
# GraphML file saved: graphml_files/network_2016_EU_ASEAN.graphml
# === Year: 2017 ===
# Top Degree Centrality:
#    Year   Country  DegreeCentrality  BetweennessCentrality
# 3  2017     Italy             0.875               0.125000
# 4  2017    France             0.875               0.125000
# 2  2017  Thailand             0.750               0.071429
# 1  2017     Spain             0.625               0.307143
# 6  2017  Cambodia             0.625               0.021429
# Top Betweenness Centrality:
#    Year   Country  DegreeCentrality  BetweennessCentrality
# 1  2017     Spain             0.625               0.307143
# 3  2017     Italy             0.875               0.125000
# 4  2017    France             0.875               0.125000
# 2  2017  Thailand             0.750               0.071429
# 6  2017  Cambodia             0.625               0.021429
#
# Top 5 Strongest Connections (Edge weight):
# Italy - France: weight=3
# Thailand - Italy: weight=2
# Thailand - France: weight=2
# Philippines - Spain: weight=1
# Philippines - Philippines: weight=1
# GraphML file saved: graphml_files/network_2017_EU_ASEAN.graphml
# /var/folders/s_/s1j9h97d2lb60zgcmh_ybvmc0000gn/T/ipykernel_81518/3457964409.py:40: DeprecationWarning: `alltrue` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `all` instead.
#   nx.draw_networkx_edges(G, pos, alpha=0.3)
# === Year: 2018 ===
# Top Degree Centrality:
#    Year  Country  DegreeCentrality  BetweennessCentrality
# 0  2018    Italy               1.0                    0.0
# 1  2018  Germany               1.0                    0.0
# Top Betweenness Centrality:
#    Year  Country  DegreeCentrality  BetweennessCentrality
# 0  2018    Italy               1.0                    0.0
# 1  2018  Germany               1.0                    0.0
#
# Top 5 Strongest Connections (Edge weight):
# Italy - Germany: weight=1
# GraphML file saved: graphml_files/network_2018_EU_ASEAN.graphml
# === Year: 2019 ===
# Top Degree Centrality:
#    Year  Country  DegreeCentrality  BetweennessCentrality
# 1  2019   France          0.909091               0.336364
# 6  2019  Finland          0.636364               0.000000
# 7  2019  Germany          0.363636               0.000000
# 8  2019  Belgium          0.363636               0.000000
# 9  2019   Poland          0.363636               0.100000
# Top Betweenness Centrality:
#     Year Country  DegreeCentrality  BetweennessCentrality
# 1   2019  France          0.909091               0.336364
# 9   2019  Poland          0.363636               0.100000
# 10  2019  Sweden          0.272727               0.081818
# 0   2019   Italy          0.181818               0.063636
# 2   2019   Spain          0.181818               0.000000
#
# Top 5 Strongest Connections (Edge weight):
# Finland - Finland: weight=4
# France - Finland: weight=3
# France - France: weight=3
# Finland - Germany: weight=3
# Finland - Belgium: weight=3
# GraphML file saved: graphml_files/network_2019_EU_ASEAN.graphml
# === Year: 2020 ===
# Top Degree Centrality:
#    Year  Country  DegreeCentrality  BetweennessCentrality
# 0  2020  Germany          1.066667               0.021542
# 1  2020   France          1.066667               0.004082
# 3  2020   Poland          1.066667               0.031066
# 4  2020    Spain          1.066667               0.021542
# 5  2020  Finland          1.066667               0.012018
# Top Betweenness Centrality:
#     Year   Country  DegreeCentrality  BetweennessCentrality
# 8   2020  Thailand          1.000000               0.144324
# 10  2020  Malaysia          0.933333               0.061285
# 13  2020  Cambodia          0.800000               0.061285
# 14  2020   Myanmar          0.800000               0.061285
# 15  2020   Belgium          0.533333               0.038904
#
# Top 5 Strongest Connections (Edge weight):
# France - Spain: weight=38
# France - Italy: weight=36
# France - France: weight=7
# Spain - Spain: weight=7
# France - Finland: weight=5
# GraphML file saved: graphml_files/network_2020_EU_ASEAN.graphml
# === Year: 2021 ===
# Top Degree Centrality:
#     Year  Country  DegreeCentrality  BetweennessCentrality
# 1   2021   France            1.0000               0.349255
# 0   2021    Italy            0.6250               0.057828
# 5   2021   Poland            0.6250               0.045606
# 11  2021  Vietnam            0.5625               0.073662
# 15  2021   Sweden            0.5625               0.030833
# Top Betweenness Centrality:
#     Year      Country  DegreeCentrality  BetweennessCentrality
# 1   2021       France            1.0000               0.349255
# 4   2021      Germany            0.4375               0.179217
# 9   2021     Cambodia            0.4375               0.154003
# 6   2021  Philippines            0.4375               0.131111
# 11  2021      Vietnam            0.5625               0.073662
#
# Top 5 Strongest Connections (Edge weight):
# Italy - Spain: weight=13
# Italy - Denmark: weight=8
# Spain - Denmark: weight=8
# France - Sweden: weight=3
# Poland - Finland: weight=3
# GraphML file saved: graphml_files/network_2021_EU_ASEAN.graphml
# === Year: 2022 ===
# Top Degree Centrality:
#     Year    Country  DegreeCentrality  BetweennessCentrality
# 1   2022     France          1.000000               0.036667
# 9   2022    Vietnam          0.933333               0.221633
# 8   2022  Indonesia          0.866667               0.003175
# 3   2022      Spain          0.800000               0.003175
# 10  2022   Malaysia          0.800000               0.274218
# Top Betweenness Centrality:
#     Year      Country  DegreeCentrality  BetweennessCentrality
# 10  2022     Malaysia          0.800000               0.274218
# 9   2022      Vietnam          0.933333               0.221633
# 4   2022       Poland          0.733333               0.175556
# 11  2022  Philippines          0.400000               0.128571
# 15  2022      Denmark          0.466667               0.098345
#
# Top 5 Strongest Connections (Edge weight):
# Thailand - Indonesia: weight=14
# Thailand - Malaysia: weight=10
# Singapore - Indonesia: weight=9
# Italy - France: weight=8
# Thailand - Singapore: weight=8
# GraphML file saved: graphml_files/network_2022_EU_ASEAN.graphml
# === Year: 2023 ===
# Top Degree Centrality:
#     Year   Country  DegreeCentrality  BetweennessCentrality
# 0   2023     Spain            1.0000               0.004861
# 2   2023    France            1.0000               0.009802
# 3   2023  Thailand            1.0000               0.039444
# 12  2023    Sweden            0.9375               0.068095
# 14  2023    Poland            0.8750               0.010913
# Top Betweenness Centrality:
#     Year    Country  DegreeCentrality  BetweennessCentrality
# 16  2023    Myanmar            0.7500               0.145337
# 10  2023  Indonesia            0.8125               0.126052
# 6   2023   Malaysia            0.8125               0.118800
# 15  2023    Finland            0.7500               0.077887
# 12  2023     Sweden            0.9375               0.068095
#
# Top 5 Strongest Connections (Edge weight):
# Thailand - Vietnam: weight=18
# France - France: weight=16
# Spain - France: weight=10
# France - Thailand: weight=10
# Spain - Thailand: weight=7
# GraphML file saved: graphml_files/network_2023_EU_ASEAN.graphml
# === Year: 2024 ===
# Top Degree Centrality:
#     Year    Country  DegreeCentrality  BetweennessCentrality
# 6   2024    Vietnam            1.1250               0.066796
# 1   2024   Malaysia            1.1250               0.200605
# 10  2024  Indonesia            1.1250               0.142609
# 11  2024   Thailand            1.1250               0.011756
# 5   2024     France            1.0625               0.000000
# Top Betweenness Centrality:
#     Year    Country  DegreeCentrality  BetweennessCentrality
# 1   2024   Malaysia            1.1250               0.200605
# 13  2024    Finland            0.8750               0.174881
# 10  2024  Indonesia            1.1250               0.142609
# 15  2024    Myanmar            0.5625               0.080159
# 6   2024    Vietnam            1.1250               0.066796
#
# Top 5 Strongest Connections (Edge weight):
# France - France: weight=36
# Philippines - Vietnam: weight=30
# Vietnam - Singapore: weight=30
# France - Spain: weight=27
# Philippines - Indonesia: weight=26
# GraphML file saved: graphml_files/network_2024_EU_ASEAN.graphml
# === Year: 2025 ===
# Top Degree Centrality:
#    Year    Country  DegreeCentrality  BetweennessCentrality
# 0  2025  Indonesia          1.133333               0.177778
# 2  2025    Germany          1.066667               0.062698
# 3  2025    Finland          1.066667               0.146825
# 4  2025     Sweden          1.066667               0.167381
# 5  2025      Spain          1.066667               0.007937
# Top Betweenness Centrality:
#     Year    Country  DegreeCentrality  BetweennessCentrality
# 0   2025  Indonesia          1.133333               0.177778
# 4   2025     Sweden          1.066667               0.167381
# 14  2025     Poland          1.066667               0.153889
# 3   2025    Finland          1.066667               0.146825
# 15  2025   Cambodia          1.066667               0.141905
#
# Top 5 Strongest Connections (Edge weight):
# Spain - France: weight=121
# France - France: weight=106
# Germany - France: weight=67
# Spain - Spain: weight=57
# France - Vietnam: weight=56
# GraphML file saved: graphml_files/network_2025_EU_ASEAN.graphml

# %%
import pandas as pd
import matplotlib.pyplot as plt

# List to store Louvain detection results
results = []

for year, counts in pairs_per_year.items():
    G = nx.Graph()
    for (c1, c2), weight in counts.items():
        G.add_edge(c1, c2, weight=weight)

    if len(G.nodes()) == 0:
        continue

    partition = community_louvain.best_partition(G, weight='weight')

    # Create dictionary for communities and their countries
    community_groups = {}
    for node, comm_id in partition.items():
        community_groups.setdefault(comm_id, set()).add(node)

    # Match communities with region groups and calculate metrics
    for comm_id, countries in community_groups.items():
        for region, region_countries in region_groups.items():
            matched = countries & region_countries
            if matched:
                precision = len(matched) / len(countries)
                recall = len(matched) / len(region_countries)
                f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0
                results.append({'Year': year, 'Community': comm_id, 'Region': region, 
                                'Precision': precision, 'Recall': recall, 'F1': f1})

# Create DataFrame from results
df = pd.DataFrame(results)

# Calculate average Precision, Recall, and F1 by year and region
avg_per_year = df.groupby(['Year', 'Region'])[['Precision', 'Recall', 'F1']].mean().reset_index()

# 📈 Plot bar charts for each metric
metrics = ['Precision', 'Recall', 'F1']
for metric in metrics:
    plt.figure(figsize=(12, 6))
    for region in region_groups.keys():
        region_data = avg_per_year[avg_per_year['Region'] == region]
        plt.bar(region_data['Year'].astype(str), region_data[metric], alpha=0.7, label=region)
    plt.ylabel(metric)
    plt.title(f'Yearly Average {metric} by Region')
    plt.legend()
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.savefig(f'{metric.lower()}_barplot.png', dpi=300)
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# EU+ASEAN country list (matches with the previous code)
eu_asean_countries = [
    'France', 'Germany', 'Sweden', 'Belgium', 'Denmark', 'Poland', 'Finland', 'Italy', 'Spain',
    'Thailand', 'Vietnam', 'Indonesia', 'Malaysia', 'Singapore', 'Cambodia', 'Philippines', 'Myanmar'
]

for year, counts in pairs_per_year.items():
    G = nx.Graph()
    for (c1, c2), weight in counts.items():
        if c1 in eu_asean_countries and c2 in eu_asean_countries:
            G.add_edge(c1, c2, weight=weight)
    
    if len(G.nodes()) == 0:
        print(f"\n=== Year: {year} ===\nNo EU/ASEAN nodes.")
        continue

    # Calculate Degree Centrality and select the highest node (centroid)
    degree_centrality = nx.degree_centrality(G)
    centroid_country = max(degree_centrality, key=degree_centrality.get)

    # Extract connected countries and edge weights of the centroid node
    neighbors = list(G.neighbors(centroid_country))
    weights = [G[centroid_country][neighbor]['weight'] for neighbor in neighbors]
    
    if not neighbors:
        print(f"\n=== Year: {year} ===\nNo connections for centroid {centroid_country}.")
        continue

    # Plot bar chart
    plt.figure(figsize=(10, 5))
    plt.bar(neighbors, weights, color='skyblue')
    plt.xlabel('Connected Country')
    plt.ylabel('Edge Weight')
    plt.title(f'Year {year}: Strongest Centroid ({centroid_country}) Connections')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
import pandas as pd

# List for storing quantitative metrics
metrics = []

for year, counts in pairs_per_year.items():
    G = nx.Graph()
    for (c1, c2), weight in counts.items():
        G.add_edge(c1, c2, weight=weight)
    
    if len(G.nodes()) == 0:
        continue

    partition = community_louvain.best_partition(G, weight='weight')
    
    community_groups = {}
    for node, comm_id in partition.items():
        community_groups.setdefault(comm_id, set()).add(node)
    
    for comm_id, countries in community_groups.items():
        for region, region_countries in region_groups.items():
            matched = countries & region_countries
            if matched:
                precision = len(matched) / len(countries)
                recall = len(matched) / len(region_countries)
                f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0
                metrics.append({
                    'Year': year,
                    'Community': comm_id,
                    'Region': region,
                    'MatchedCountries': list(matched),
                    'Precision': round(precision, 2),
                    'Recall': round(recall, 2),
                    'F1': round(f1, 2)
                })

# DataFrame
metrics_df = pd.DataFrame(metrics)
metrics_df
# Out:
#     Year  Community         Region  \
# 0   2013          0             EU
# 1   2013          0  North_America
# 2   2015          0          ASEAN
# 3   2015          0             EU
# 4   2015          0  North_America
# ..   ...        ...            ...
# 86  2025          5             EU
# 87  2025          5  North_America
# 88  2025          6          ASEAN
# 89  2025          6             EU
# 90  2025          6  North_America
#
#                                      MatchedCountries  Precision  Recall    F1
# 0   [Belgium, Sweden, Poland, France, Finland, Ger...       0.31    0.90  0.46
# 1                                            [Canada]       0.03    0.33  0.06
# 2                                           [Vietnam]       0.01    0.10  0.03
# 3         [Belgium, Sweden, France, Finland, Denmark]       0.07    0.50  0.13
# 4                                            [Mexico]       0.01    0.33  0.03
# ..                                                ...        ...     ...   ...
# 86              [Germany, France, Spain, Netherlands]       0.27    0.40  0.32
# 87                                           [Canada]       0.07    0.33  0.11
# 88                                [Thailand, Myanmar]       0.12    0.20  0.15
# 89                                            [Italy]       0.06    0.10  0.07
# 90                                           [Mexico]       0.06    0.33  0.10
#
# [91 rows x 7 columns]
